# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%capture
# !unzip /content/drive/MyDrive/Damage_segmentation.zip

# %%
#!unzip /content/drive/MyDrive/dataQuest/Damag_segmentation.zip

# %%
# %%capture
# !pip install ultralytics

# %%
# !yolo task=segment mode=train model=yolov8s-seg.pt  data=/content/Car_Parts_Detection/data.yaml epochs=10 imgsz=640
# Out:
# Ultralytics YOLOv8.0.220 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
Image(filename='runs/segment/train2/confusion_matrix.png', width=600)

# %%
Image(filename='runs/segment/train2/results.png', width=600)

# %%
Image(filename='runs/segment/train2/val_batch1_pred.jpg', width=600)

# %%
# !yolo task=segment mode=val model=runs/segment/train2/weights/best.pt data=/content/Car_Parts_Detection/data.yaml
# Out:
# Ultralytics YOLOv8.0.220 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s-seg summary (fused): 195 layers, 11785018 parameters, 0 gradients, 42.5 GFLOPs
# val: Scanning /content/Car_Parts_Detection/valid/labels.cache... 1887 images, 0 backgrounds, 0 corrupt: 100% 1887/1887 [00:00<?, ?it/s]
# val: WARNING ⚠️ /content/Car_Parts_Detection/valid/images/0029502_sc-161833_jpg.rf.f0cc602cbbe567abee8c5e8097684ff0.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /content/Car_Parts_Detection/valid/images/0177909_as-0042156_jpg.rf.a43d7ffcbc344ee0d2a2a0a4b7015c87.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /content/Car_Parts_Detection/valid/images/0237724_as-0068252_jpg.rf.b365be8c22a06734c9fd1a0774eb1d4c.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /content/Car_Parts_Detection/valid/images/0259102_sc-150122_jpg.rf.6df8746593987da8438d6d3ff69d6352.jpg: 1 duplicate labels removed
# ...

# %%
# !yolo task=segment mode=predict model=/content/runs/segment/train2/weights/best.pt conf=0.25 source=/content/Car_Parts_Detection/test/images save=true
# Out:
# Ultralytics YOLOv8.0.220 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s-seg summary (fused): 195 layers, 11785018 parameters, 0 gradients, 42.5 GFLOPs
#
# image 1/949 /content/Car_Parts_Detection/test/images/0001176_as-0066940_jpg.rf.cb450b3d48f2913b0df9568d9238ec1e.jpg: 480x640 1 Frontdoor, 2 Rearbumpers, 1 Reardoor, 1 Rearfender, 1 Rockerpanel, 1 Trunklid, 258.4ms
# image 2/949 /content/Car_Parts_Detection/test/images/0001299_sc-150389_jpg.rf.0d76318f9f48be6367b7b95600c3e1e0.jpg: 480x640 2 Frontdoors, 16.7ms
# image 3/949 /content/Car_Parts_Detection/test/images/0001552_as-0073135_jpg.rf.478764673413e045b3697955661d61a5.jpg: 480x640 1 Bonnet, 1 Frontbumper, 1 Frontdoor, 1 Frontfender, 1 Headlights, 1 Reardoor, 1 Rockerpanel, 16.7ms
# image 4/949 /content/Car_Parts_Detection/test/images/0002076_as-0069974_jpg.rf.d46beaab284dcff928f8486d52f36a13.jpg: 480x640 1 Rearlamp, 16.7ms
# ...

# %%
Image(filename='/content/runs/segment/predict2/0012584_as-0015800_jpg.rf.aa468e13c6bcfb4ad5e6394c6c1ac261.jpg', width=600)

# %% [markdown]
# # Damage segmentation (only one class which is "damage")

# %%
# !yolo task=segment mode=train model=yolov8s-seg.pt  data=/content/data.yaml epochs=10 imgsz=640 lr0=0.001
# Out:
# ...
# 100% 22.8M/22.8M [00:00<00:00, 289MB/s]
# Ultralytics YOLOv8.0.220 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
Image(filename='runs/segment/train/confusion_matrix.png', width=600)

# %%
Image(filename='runs/segment/train/results.png', width=600)

# %%
Image(filename='runs/segment/train/val_batch1_pred.jpg', width=600)

# %%
# !yolo task=segment mode=val model=runs/segment/train/weights/best.pt data=/content/data.yaml
# Out:
# Ultralytics YOLOv8.0.220 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s-seg summary (fused): 195 layers, 11779987 parameters, 0 gradients, 42.4 GFLOPs
# val: Scanning /content/valid/labels.cache... 644 images, 0 backgrounds, 0 corrupt: 100% 644/644 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 41/41 [00:18<00:00,  2.17it/s]
#                    all        644       1235      0.207      0.132     0.0728     0.0259       0.17      0.106     0.0534     0.0156
# Speed: 1.2ms preprocess, 12.5ms inference, 0.0ms loss, 2.3ms postprocess per image
# Results saved to runs/segment/val3
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo task=segment mode=predict model=/content/runs/segment/train/weights/best.pt conf=0.1 source=/content/test/images save=true
# Out:
# Ultralytics YOLOv8.0.220 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s-seg summary (fused): 195 layers, 11779987 parameters, 0 gradients, 42.4 GFLOPs
#
# image 1/429 /content/test/images/102_jpg.rf.d9fbbda57476a8cf14583c2abdcb4164.jpg: 640x640 2 Damages, 21.0ms
# image 2/429 /content/test/images/111_jpg.rf.167e56f713d3d93d01c20db45fb02fe3.jpg: 640x640 1 Damage, 21.5ms
# image 3/429 /content/test/images/113_jpg.rf.ce294dfa1a3742b94a5f7a38428aab6a.jpg: 640x640 1 Damage, 20.9ms
# image 4/429 /content/test/images/117_jpg.rf.d3d2abf4c057f82ef8f43db95540824b.jpg: 640x640 2 Damages, 20.9ms
# image 5/429 /content/test/images/139_jpg.rf.b420b0d07c86206ded1a6f8adb421ef4.jpg: 640x640 1 Damage, 21.0ms
# image 6/429 /content/test/images/140_jpg.rf.77be205029e11d2fa5113715fb7da5d3.jpg: 640x640 (no detections), 20.3ms
# image 7/429 /content/test/images/143_jpg.rf.6e2e8aedcc0cf341ef75f634b416caba.jpg: 640x640 (no detections), 16.7ms
# ...

# %%
Image(filename='/content/runs/segment/predict/117_jpg.rf.d3d2abf4c057f82ef8f43db95540824b.jpg', width=600)

# %%
Image(filename='/content/runs/segment/predict/117_jpg.rf.d3d2abf4c057f82ef8f43db95540824b.jpg', width=600)
